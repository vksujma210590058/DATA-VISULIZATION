# %% [markdown]
#     # 1undersstand the problem statement
#     # 2 collect the data
#     # 3 load data in pandas
#     # 4 cleaning data
#         # check duplicaets
#         # null value and clean null values
#         # check insconsisstendnt data
#         # outlies detcetjion
#         # eda( exploratory data analysis)
#
#
#
#
#
#
#
#
#     # 1 univariate analysis
#     # when wea re analysis single variable at atime
#     # ex. histogram distplot , boxplot
#     # 2 bivariate anallysis
#         #  when we deal with two variable at a time then we called bi variate annaysis
#     #     ex.line chart scaterplot bar plot pie cchart
#     # 3 multivarialte analysis
#     #     when we are dealing with multiple variable at a time
#     #     ex.pair plot

# %%
import pandas  as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import read
read.file_reading()
customer_churn_data=read.df
# Out:
# ['bike_buyers.csv', 'cleaned_df.xlsx', 'customer_churn_data.csv', 'IRIS.csv', 'Iris1.csv', 'output.xlsx', 'playstore.csv']
# 6 If you want to see the last one
# while file you want to see type index:2
# C:\Myimpartant_file\customer_churn_data.csv

# %%
customer_churn_data.head(30)
# this data is belongs to teclo customer data telecom company
# partner column means that customer has any partner or not
# yes=1
# no=0
#tenture means time period
# dependents means  that customer depend on the his father or on his husband or on his childres..............
# churn the last column we have to predict
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
customer_churn_data.shape
# Out:
# (7043, 21)

# %%
read.file_reading()
read.checking()
# Out:
# ['bike_buyers.csv', 'cleaned_df.xlsx', 'customer_churn_data.csv', 'IRIS.csv', 'Iris1.csv', 'output.xlsx', 'playstore.csv']
# 6 If you want to see the last one
# while file you want to see type index:2
# C:\Myimpartant_file\customer_churn_data.csv
# duplicated sometimes we cannot delete it  0
# => customerID int= 0 float= 0 string= 0 nul  0 alphanumeric= 0 other 7043 ['7590-VHVEG', 0, '7590-VHVEG', 0, '5575-GNVDE', 1]
# [n_list,f_list,s_list,al_list]
# Type_number 0,1,2..no n
# null
# => gender int= 0 float= 0 string= 7043 nul  0 alphanumeric= 0 other 0 []
# [n_list,f_list,s_list,al_list]
# Type_number 0,1,2..no n
# null
# => SeniorCitizen int= 7043 float= 0 string= 0 nul  0 alphanumeric= 0 other 0 []
# [n_list,f_list,s_list,al_list]
# Type_number 0,1,2..no n
# null
# => Partner int= 0 float= 0 string= 7043 nul  0 alphanumeric= 0 other 0 []
# [n_list,f_list,s_list,al_list]
# Type_number 0,1,2..no n
# null
# => Dependents int= 0 float= 0 string= 7043 nul  0 alphanumeric= 0 other 0 []
# ...

# %%
customer_churn_data.head(30)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
customer_churn_data.corr( numeric_only=True)
# Out:
#                 SeniorCitizen    tenure  MonthlyCharges
# SeniorCitizen        1.000000  0.016567        0.220173
# tenure               0.016567  1.000000        0.247900
# MonthlyCharges       0.220173  0.247900        1.000000

# %%
sns.boxplot(x="tenure" ,data=customer_churn_data)
# Out:
# <Axes: xlabel='tenure'>

# %%
sns.boxplot(data=customer_churn_data)
# Out:
# <Axes: >

# %%
sns.boxplot(x="SeniorCitizen",data=customer_churn_data)
# Out:
# <Axes: xlabel='SeniorCitizen'>

# %% [markdown]
# there is not any outliar in the data set
# if any outliar in my data then i  make some changes or remove that

# %%
import data_cleaning1
# female=1
# male= 0
data_cleaning1.data_cleaning()
# Out:
# ['bike_buyers.csv', 'cleaned_df.xlsx', 'customer_churn_clean_data.xlsx', 'customer_churn_data.csv', 'IRIS.csv', 'Iris1.csv', 'output.xlsx', 'playstore.csv']
# 7 If you want to see the last one
# while file you want to see type index:2
# C:\Myimpartant_file\customer_churn_clean_data.xlsx
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       1              0        1           0       1
# 1     5575-GNVDE       0              0        0           0      34
# 2     3668-QPYBK       0              0        0           0       2
# 3     7795-CFOCW       0              0        0           0      45
# 4     9237-HQITU       1              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       0              0        1           1      24
# 7039  2234-XADUH       1              0        1           1      72
# ...

# %% [markdown]
# 1. customer_clean_data is my cleaned and processed data  of the customer churn data set
# 2. and for machine learnin  i did some changes in my data set
# 3. gender column female =1 and male =0|
# 4. and in the other column for yes =1 and no=0

# %% [markdown]
# >>read is my is my python file that help me the read the data easily and read.py this
# is my module

# %%
import read
read.file_reading()
customer_clean_data=read.df
# Out:
# ['bike_buyers.csv', 'cleaned_df.xlsx', 'cleaned_df_cus_curn.xlsx', 'customer_churn_clean_data.xlsx', 'customer_churn_data.csv', 'IRIS.csv', 'Iris1.csv', 'output.xlsx', 'playstore.csv']
# 8 If you want to see the last one
# while file you want to see type index:2
# C:\Myimpartant_file\cleaned_df_cus_curn.xlsx

# %%
customer_clean_data.head(30)
# read.file_reading()
# read.checking()
# Out:
#     customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0   7590-VHVEG       1              0        1           0       1
# 1   5575-GNVDE       0              0        0           0      34
# 2   3668-QPYBK       0              0        0           0       2
# 3   7795-CFOCW       0              0        0           0      45
# 4   9237-HQITU       1              0        0           0       2
# 5   9305-CDSKC       1              0        0           0       8
# 6   1452-KIOVK       0              0        0           1      22
# 7   6713-OKOMC       1              0        0           0      10
# 8   7892-POOKP       1              0        1           0      28
# 9   6388-TABGU       0              0        0           1      62
# 10  9763-GRSKD       0              0        1           1      13
# 11  7469-LKBCI       0              0        0           0      16
# 12  8091-TTVAX       0              0        1           0      58
# ...

# %%
customer_clean_data.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       1              0        1           0       1
# 1  5575-GNVDE       0              0        0           0      34
# 2  3668-QPYBK       0              0        0           0       2
# 3  7795-CFOCW       0              0        0           0      45
# 4  9237-HQITU       1              0        0           0       2
#
#    PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# 0             0              0             DSL               0  ...
# 1             1              0             DSL               1  ...
# 2             1              0             DSL               1  ...
# 3             0              0             DSL               1  ...
# 4             1              0     Fiber optic               0  ...
#
#   DeviceProtection  TechSupport  StreamingTV  StreamingMovies        Contract  \
# ...

# %% [markdown]
# >>  i will check my file data type
# this is correct we can say

# %%
customer_clean_data.dtypes
# Out:
# customerID           object
# gender                int64
# SeniorCitizen         int64
# Partner               int64
# Dependents            int64
# tenure                int64
# PhoneService          int64
# MultipleLines         int64
# InternetService      object
# OnlineSecurity        int64
# OnlineBackup         object
# DeviceProtection      int64
# TechSupport           int64
# StreamingTV           int64
# StreamingMovies       int64
# Contract             object
# PaperlessBilling      int64
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int64
# dtype: object

# %%
customer_clean_data=read.df

# %% [markdown]
# >> we will check the data correlation
#
# >> customer Id and gender column is not much important we will ignore that column

# %%
customer_clean_data.corr(numeric_only=True)
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000       0.001874  0.001808   -0.010517 -0.005106
# SeniorCitizen     0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner           0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents       -0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure           -0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService      0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines     0.008414       0.142948  0.142057   -0.024526  0.331941
# OnlineSecurity    0.017021      -0.038653  0.143106    0.080972  0.327203
# DeviceProtection  0.002105       0.059428  0.153786    0.013963  0.360653
# TechSupport       0.009212      -0.060625  0.119999    0.063268  0.324221
# StreamingTV       0.008393       0.105378  0.124666   -0.016558  0.279756
# StreamingMovies   0.010487       0.120176  0.117412   -0.039741  0.286111
# ...

# %% [markdown]
# # this time for data visualization

# %% [markdown]
# >> one column visulization  we use histogram  distplot or histplot this will show the count in  the
# y axis

# %%
customer_clean_data.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       1              0        1           0       1
# 1  5575-GNVDE       0              0        0           0      34
# 2  3668-QPYBK       0              0        0           0       2
# 3  7795-CFOCW       0              0        0           0      45
# 4  9237-HQITU       1              0        0           0       2
#
#    PhoneService  MultipleLines InternetService  OnlineSecurity  ...  \
# 0             0              0             DSL               0  ...
# 1             1              0             DSL               1  ...
# 2             1              0             DSL               1  ...
# 3             0              0             DSL               1  ...
# 4             1              0     Fiber optic               0  ...
#
#   DeviceProtection  TechSupport  StreamingTV  StreamingMovies        Contract  \
# ...

# %%
# sns.histplot(data=customer_clean_data)
# Out:
# KeyboardInterrupt
# Error in callback <function _draw_all_if_interactive at 0x0000028E407E9620> (for post_execute):
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x0000028E3D239120> (for post_execute):
# KeyboardInterrupt

# %%
sns.histplot(x="gender",data=customer_clean_data)
plt.show()

# %%
sns.histplot(x="SeniorCitizen",data=customer_clean_data)
plt.show()
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='Count'>

# %% [markdown]
# >> here seniorcitizen are not in out data set
#  and they are not very much  intrested in the telecome company
#  only young or adult generration is intrested in the our serivice

# %% [markdown]
# 1. partner_column is showing that parnter yes custmer and  those who has not partner customer are same number
# 2. Dependant column is showing that those who are dependant on his parentents or children... they are not taking our services  resion  because they are dependend on someones
# 3. tenure_column most of the customer or more customer refused our serverice with in one year  or half year
# 4. phone_services most of customer have phone service
# 5. about the multiple lines cable is for yes and no it is around the same
# 6.

# %%
for i in list(customer_clean_data.iloc[:,3:].columns):
#     print(i)
    sns.histplot(x=f"{i}",data=customer_clean_data)
    plt.show()

# %%
pie=customer_clean_data.InternetService.value_counts()
pie.index
pie
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %% [markdown]
# >>Internet service>> around 20 percenct person has no internet service
# we  can add them in our services and they can buy our sevices

# %%
plt.pie(x=customer_clean_data.InternetService.value_counts(),labels=pie.index,autopct="%1.0f%%")
plt.show()

# %%
for i in list(customer_clean_data.iloc[:,[9,10,11,12,13,15]].columns):
    print(i)
    plt.pie(x=customer_clean_data[f"{i}"].value_counts(),labels=customer_clean_data[f"{i}"].value_counts().index,autopct="%1.0f%%")
    plt.show()
# Out:
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# Contract

# %% [markdown]
# ONLINESECURITY>> THIS COLUMN 70 PERCENT CUSTOMER DONOT HAVE ONLINE BETTER SECURITY  THAT WE CAN PROMISE TO PROVIDE THEM
# SECURITY AND IF WE DONONOT HAVE THIS OFFER THEN WE SHOULD ADD THIS      IF THE PEOPLE HAVE NO FEAR FOR SECUERITY THEN THEY
# WILL NOT CHURN OUR SERVICES
# >> ONLINE BACKUP  MOST OF PEOPLE DONOT PREFER THIS THOSE WHO PREFER AND THOSE WHO NOT PREFER IT
# WHAT ARE DIFFRENCE BETHWEEN THEN
# >>> DEVICE PROTECTION  AROUND 65 PERCENT CUSTOMER HAS NO DIVICE PROTECTION  THEY DONOT LIKE THIS
# >> TECH SUPPORT CUSTOMER NO TYPE ARE AROUND 70 PERCENT
# >>STREAMINT TV
# >>MOVIES WACHING
# >>PYMENT

# %% [markdown]
# #  BIVARIATE VISUALIZATION

# %%
# CAMPARE ABOUT THE THOSE WHO have multipleline and curn column what are relation 

# how many leaves

# %%
m_sum_churn=customer_clean_data.groupby(["MultipleLines","Churn"]).agg({"Churn":"count"})
print(m_sum_churn.columns)
m_sum_churn
# Out:
# Index(['Churn'], dtype='object')
#                      Churn
# MultipleLines Churn
# 0             0       3053
#               1       1019
# 1             0       2121
#               1        850

# %%
def mysql1(function):
    import pandas as pd
#     import read
    from IPython.display import display, Image, HTML

#  Displaying an image
# display(Image(filename='example.png'))

# # Displaying HTML content
# html_#content = "<h1>Hello, World!</h1>"
# display(HTML(html_content))

    
#     file=input()
#     import matplot.pyplot as plt
    function=f'''{function}'''
    split_list= function.split(" ")
    result_list = [item for sublist in split_list for item in sublist.split('\n')]
    final_list=[]
    for i in result_list:
        if i!="":
            final_list.append(i)
    a=final_list
    c_list=["select","from","where","groupby","having","limit"]

    j=0
    b=[]
    while j<=len(c_list)-1:
        if  c_list[j] in a:
            b.append(c_list[j])
        j=j+1





    dic={}

    try:
        for i,value in  enumerate (b):
            j=[]
            if i==len(b)-1:
                p=a.index(value)+1

                while p<=len(a)-1:
                    j.append(a[p])
                    p=p+1
                dic[b[i]]=j

            elif b[i] in a:
                p=a.index(value)+1
                while p<=a.index(b[i+1])-1:
                    j.append(a[p])
                    p=p+1
                dic[b[i]]=j
   
    except:
        
        print("its ok ")
#     print(dic)

#     keys=list(dic.keys())

    condition=''

    agg=''
    gr=''
    groupby_agg=''
    dfs=dic['from'][0]
    not_group_by=''
    if "groupby" not in list(dic.keys()) and "*" not in dic["select"]:
        not_group_by=dic["select"]
#         print(not_group_by)
        not_group_by="["+str(not_group_by)+"]"
#         print(not_group_by)
    if "where" in list(dic.keys()):
#         print(eval(dfs))
        cond=dic["where"][0] 
        d=dic["where"][1] + str(dic["where"][2])
        condition='['+dfs+'.'+  cond + d+"]"
#         print(eval(condition))
    if "groupby" in list(dic.keys()):
        
       
        agg_col={}
        groupby_col=[]
        for i in dic["groupby"]:



            i=i.replace(")","")
            if "(" in i:


                split=list(i.split("("))
#                 print(split)
                if split[1] not in agg_col:


                    agg_col[split[1]]=[split[0]]
                        
#                     print(agg_col)
                else: 
#                     print(agg_col)
                    agg_col[split[1]].append(split[0])
#                     print(agg_col)
            else:

                groupby_col.append(i)
                print(groupby_col)
#         print(groupby_col)
#         print(agg_col)
        agg=".agg(agg_col)"
        gr=".groupby(groupby_col)"
        groupby_agg=gr+agg
        
    if "groupby" in b:
        global q
        q=dfs+condition+groupby_agg
#         q1=q
        q=q+".reset_index()"
    else:
        q=dfs+condition+not_group_by
#     print(q)
#     print(q)
    grouped_df=eval(q)
    display(grouped_df)
#     q1=eval(q1)
#     print(grouped_df[('Gender',     '')])
#     print(q1.reset_index().columns,"co00lumns")
#     print(grouped_df)
#     return  eval(q
#     print(grouped_df)
#     print(q)
#     print(len(groupby_col))
#     grouped_df[iloc[]]
    if "groupby" in list(dic.keys()):
#         print("ok")
#         print(len(groupby_col))
        if len(groupby_col)==0:
            print("yes")
            col_vis1 = groupby_col 
            col_vis = "grouped_df" + str(col_vis1)

            for column, funcs in agg_col.items():
        #         print("Column:", column)
                for func in funcs:
                    func1=f"'{func}'"
        #             print(func1)
                    col_vis=col_vis+","+"grouped_df"+f"['{column}']"+f"[{func1}]"
        #             print("Function:", func)

            col_vis="["+col_vis+"]"
#             print(col_vis)
            
        else:
#             print("wait")
            grouped_d_r=grouped_df.iloc[:,:len(groupby_col)]
            # Dropping all numeric columns
#             grouped_d_r= grouped_d_r.select_dtypes(exclude=['number'])
#             grouped_d_r
            # Displaying the DataFrame after dropping numeric columns
#             print("\nDataFrame after dropping numeric columns:")
#             print(grouped_d_r)
            list_global=[]
            legends_name=[]
            while len(list(grouped_d_r.columns))>1:
                unique_counts = grouped_d_r.nunique()
                min_unique_value = unique_counts.min()

                # Find columns that have the minimum unique value count
                min_unique_columns = unique_counts[unique_counts == min_unique_value].index

                # Select the last column(s) among those with the same minimum unique values
                if len(min_unique_columns) > 1:
                    col_name_min = min_unique_columns[-1]  # Choose the last column among multiple columns with the same minimum count
                else:
                    col_name_min = min_unique_columns[0]  #
#                 print(col_name_min,"men")
#                 print(grouped_d_r[col_name_min[0]])
#                 df.set_index([('Gender', ''), ('Income', ''), ('Income', 'mean')], inplace=True)

#                 print(grouped_d_r)
                print(grouped_df)
#                 grouped_data_col=list(grouped_df.columns)
#                 grouped_df=grouped_df.set_index(inplace=True)
#                 print(grouped_df)
                grouped_data_col=grouped_df.columns
#                 print(grouped_data_col)
#                 print(grouped_data_col)
#                 print(grouped_data_col)
                j=len(groupby_col)
#                 print(grouped_df[("Income","")])
                arg=1
                while j<=len(grouped_data_col)-1:
#                     print(len(grouped_data_col)-1)
#                     print(j,"jjjjjjjjjjjjj")
                    for i in list(grouped_d_r[col_name_min[0]].unique()):
#                         print(i,"male")
#                         print("for")
#                         print(i)
#                         print('333',tuple(col_name_min))
#                         print(grouped_df[grouped_df[("Gender","")]=="Female"][("Income","")])
#                         print(grouped_df[grouped_df[tuple(col_name_min)]==i][grouped_data_col[j]],"4444444")
#                         print(grouped_data_col[j][0],"thos")
                        globals()[f"{i}_{j}"]=grouped_df[grouped_df[tuple(col_name_min)]==i][grouped_data_col[j]]
#                         print(grouped_df[grouped_df["Gender"]=='Female']["mean Age"],'444444')
#                         print('col',globals()[f"{i}_{j}"])
#                         print(female_1)
                        legends_name.append(f"{col_name_min}_{i}_{grouped_data_col[j]}")
                        list_global.append(globals()[f"{i}_{j}"])
#                         print("global")
                        arg=arg+1
#                         list_global1.append(grouped_df[grouped_data_col[j]].unique())
                    
                    j=j+1
                        
                grouped_d_r.drop(col_name_min[0],axis=1 ,inplace=True)
            
#             print("ggggggggggggggggggggggggggggggggggggggg")
#             print(list_global,"gggggggggggggggggggggggggggggggggggggggggggggggggggg")
#             print(grouped_d_r.iloc[:,0].unique())
            list_global.insert(0,grouped_d_r.iloc[:,0].unique())
#             list_global=list_global+list_global1
#             print(list_global)
            import group_bar00
            title=my[my.index("groupby ")+8:].replace(" "," vs ").upper()
            return  group_bar00.group_bar_graph(*list_global,legends_name=legends_name,Title_name=title)
            
            
    else:
        col_vis="grouped_df"
        for i in dic["select"]:
#                 print(col_vis)
            col_vis=col_vis+f"['{i}']"+","

#                 print(col_vis)
        # Perform operations using 'column' and 'func'
        # For instance, you could do something like:
        # result = your_data.groupby(groupby_col)[column].agg(func)
        # print(result)
        col_vis="["+ col_vis +"]"
#             print(col_vis)
#     print(col_vis)

#         g["Gender"],g["Age"]["mean"],g["Income"]["mean"]]
    import group_bar
    
#     print(yes)
#     col_vis=input("Type column  saperatet by comma")

    col_vis=eval(col_vis)

#     print(col_vis)
#     title=input("TITLE=>")
    title=titile=my[my.index("groupby ")+8:].replace(" "," vs ").upper()
    
    return  group_bar.group_bar_graph(*col_vis,Title_name=title)

#     print("sorry")
while True:
    
    
    my=input("Type Sql Syntax To Break Type N =>")
#     my="select * from data groupby   Age      mean(Income)"
    if my.lower()=="n" or my.lower()=="no":
        break
    else:
        mysql1(my)
# i have to make this more cleglobal()[f"{column_name_min}_{i}"]anr or the  without group datra
# i can give the defaault argument for the legent
# Out:
# Type Sql Syntax To Break Type N => select * from customer_clean_data groupby MultipleLines Churn count(Churn)
# ['MultipleLines']
# ['MultipleLines', 'Churn']
#   MultipleLines Churn
#                       count
# 0             0     0  3053
# 1             0     1  1019
# 2             1     0  2121
# 3             1     1   850
#   MultipleLines Churn
#                       count
# 0             0     0  3053
# 1             0     1  1019
# 2             1     0  2121
# 3             1     1   850
# [0 1]
# C:\Users\vksuj\AppData\Local\Temp\ipykernel_14004\2914148299.py:218: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   grouped_d_r.drop(col_name_min[0],axis=1 ,inplace=True)
# Type Sql Syntax To Break Type N =>select * from customer_clean_data groupby PhoneService Churn count(Churn)
# ['PhoneService']
# ['PhoneService', 'Churn']
#   PhoneService Churn
#                      count
# 0            0     0   512
# ...

# %%
import multi_col_vis1
# Out:
# ['bike_buyers.csv', 'cleaned_df.xlsx', 'cleaned_df_cus_curn.xlsx', 'customer_churn_clean_data.xlsx', 'customer_churn_data.csv', 'IRIS.csv', 'Iris1.csv', 'output.xlsx', 'playstore.csv']
# 8 If you want to see the last one
# while file you want to see type index:2
# C:\Myimpartant_file\cleaned_df_cus_curn.xlsx
# Type Sql Syntax To Break Type N =>select * from read.df groupby TechSupport Churn count(Churn)
# ['TechSupport']
# ['TechSupport', 'Churn']
#   TechSupport Churn
#                     count
# 0           0     0  3440
# 1           0     1  1559
# 2           1     0  1734
# 3           1     1   310
#   TechSupport Churn
#                     count
# 0           0     0  3440
# 1           0     1  1559
# 2           1     0  1734
# 3           1     1   310
# [0 1]
# C:\Users\vksuj\multi_col_vis1.py:225: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   grouped_d_r.drop(col_name_min[0],axis=1 ,inplace=True)
# ...

# %%
# Calculate counts for each category of PhoneService and Churn
counts = customer_clean_data.groupby(['PhoneService', 'Churn']).size().reset_index(name='Count')

# Create the bar plot using sns.barplot with estimator set to 'sum' (to display counts)
sns.barplot(x='PhoneService', y='Count', hue='Churn', data=counts, estimator=sum)
plt.show()
print(counts)
# Out:
#    PhoneService  Churn  Count
# 0             0      0    512
# 1             0      1    170
# 2             1      0   4662
# 3             1      1   1699

# %% [markdown]
# 1.  syntax>> those customer donot have multiples lines -- in these customer no leaveing our survisce  type customer is  three times of  yes type (leaving) customer
# and for those who have multiple connection line in these customers no leaveinng type customer is 2.5 times of yes type(churn) customer
#
#
# 2. those person donnot have phoneservice in these customer

# %%
plt.pie(x=m_sum_churn.Churn,labels=m_sum_churn.MultipleLines,autopct="%1.0f%%")
plt.show()

# %%
m_sum_churn=customer_clean_data.groupby(["PhoneService"]).agg({"Churn":"sum"}).reset_index()
m_sum_churn.columns
m_sum_churn
# Out:
#    PhoneService  Churn
# 0             0    170
# 1             1   1699

# %%
plt.pie(x=m_sum_churn.Churn,labels=m_sum_churn.PhoneService,autopct="%1.0f%%")
plt.show()
